# %% [markdown]
# <a href="https://colab.research.google.com/github/krithi-ks/flyrankAI-ML/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/krithi-ks/flyrankAI-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Set Up

# %%
# ML-02 — Setup
# Clone the official FlyRank starter repository when running in Colab
# and move to the repository root.

import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(
            ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
            check=True
        )

    os.chdir(REPO_DIR)

    subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "-q",
            "-r",
            "requirements.txt"
        ],
        check=True
    )
else:
    # Find the repository root from wherever the notebook started.
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())

assert os.path.exists(
    "data/raw/content_refresh_anonymized.csv"
), "starter CSV not found — are you at the repo root?"

print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I am choosing Lane 2: Refresh / Content Opportunity Scoring. My goal is to identify which content pages should be reviewed first for actions such as refresh, expansion, protection, pruning, or monitoring. I chose this lane because it connects observable search and content signals to a practical decision: helping a reviewer prioritize limited time and effort. It also allows me to start with a transparent baseline and later compare it with machine learning methods to see whether a learned ranking can improve the prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# ML-02 Section 1: Provisional lane check

lane = "Lane 2: Refresh / Content Opportunity Scoring"

print("Provisional lane:", lane)
print("Focus: Prioritize content pages for human review based on observable signals.")
# Out:
# Provisional lane: Lane 2: Refresh / Content Opportunity Scoring
# Focus: Prioritize content pages for human review based on observable signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The main question is: Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring based on observable search, content, and engagement signals?
#
# The decision supported by this work is the prioritization of pages for human review. A content or SEO reviewer would use the ranked output to decide which pages deserve attention first and what type of review may be appropriate. A wrong recommendation could waste limited review time, cause unnecessary changes to a page, or cause a potentially valuable page to receive less attention than a lower-priority page. Therefore, the system will be designed as decision support rather than an automatic guarantee of the outcome of a content change.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# ML-02 — Section 2: Check that the data supports the decision

import pandas as pd

# Load the official starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Fields relevant to the Lane 2 decision
required_columns = [
    "content_id",
    "impressions_90d",
    "sessions_90d",
    "content_age_days",
    "trend_direction"
]

missing_columns = [
    column for column in required_columns
    if column not in df.columns
]

print("Dataset loaded successfully.")
print(f"Total rows: {len(df):,}")

if missing_columns:
    print("Missing required fields:", missing_columns)
else:
    print("All required Lane 2 fields are available.")
# Out:
# Dataset loaded successfully.
# Total rows: 30,000
# All required Lane 2 fields are available.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
# The starter dataset contains 30,000 content rows and 30,000 pages with impressions. There are also 16,262 pages with a downward trend according to the available trend field. These initial observations show that the dataset contains measurable content performance and movement signals that can support further investigation into page prioritization and refresh opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Calculate real numbers relevant to Lane 2
total_rows = len(df)
pages_with_impressions = (df["impressions_90d"] > 0).sum()
downward_pages = (df["trend_direction"].str.lower() == "down").sum()

# Display the results
print(f"Total content rows: {total_rows:,}")
print(f"Pages with impressions: {pages_with_impressions:,}")
print(f"Pages with downward trend: {downward_pages:,}")
# Out:
# Total content rows: 30,000
# Pages with impressions: 30,000
# Pages with downward trend: 16,262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project can identify observed and measured patterns in search, content, and engagement data and use those signals to produce a directional, evidence-based ranking of pages for human review. The final output will be decision support rather than an automatic decision.
#
# I cannot claim that a recommended refresh will cause a page to recover, because the available data does not provide a controlled causal experiment. I also cannot claim to predict Google's ranking algorithm or prove that a particular signal is a Google ranking factor. Any conclusions will therefore be presented as observed, measured, directional, and supported by the available data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Basic check: confirm the dataset and required Lane 2 fields are available

required_columns = [
    "content_id",
    "impressions_90d",
    "sessions_90d",
    "content_age_days",
    "trend_direction"
]

missing_columns = [col for col in required_columns if col not in df.columns]

print("Rows:", len(df))
print("Required columns present:", len(missing_columns) == 0)

if missing_columns:
    print("Missing columns:", missing_columns)
else:
    print("All required Lane 2 starter fields are present.")
# Out:
# Rows: 30000
# Required columns present: True
# All required Lane 2 starter fields are present.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
